# %% [markdown]
# # inference - ResNet50

# %%
import cv2
import glob
import os
import vart
import xir
# import tqdm

import numpy as np

# %% [markdown]
# ***
#
# ## setting

# %%
dataset_dir = 'val'

xmodel_path = 'deploy.xmodel'
words_txt_path = 'words.txt'

# %% [markdown]
# ***
#
# ## functions

# %%
def get_child_subgraph_dpu(graph: xir.Graph) -> list[xir.Subgraph]:
    """obtain dpu subgrah.
    """
    assert graph, '"graph" should not be None.'
    
    root_subgraph = graph.get_root_subgraph()
    assert root_subgraph, 'Failed to get root subgraph of input Graph object.'
    if root_subgraph.is_leaf:
        return []

    child_subgraphs = root_subgraph.toposort_child_subgraph()
    assert child_subgraphs
    return [
        cs for cs in child_subgraphs
        if cs.has_attr('device') and cs.get_attr('device').upper() == 'DPU'
    ]


def preprocess_one_image(
    image_path: str, fix_scale: float, *,
    width: int = 224, height: int = 224
) -> np.ndarray:
    """Pre-process for ResNet50.
    """
    # in the order of [B, G, R]
    means = np.asarray([104.0, 107.0, 123.0])
    scales = np.asarray([1.0, 1.0, 1.0])

    image = cv2.resize(cv2.imread(image_path), (width, height))
    image = (image - means) * scales * fix_scale
    return image.astype(np.int8)


def calc_softmax(
    data: np.ndarray, scale: float
) -> np.ndarray:
    """Calculate softmax.
    
    Args:
        data: data to be calculated
        scale: scale

    Returns:
        softamx result
    """
    data_ = np.exp(data * scale)
    return data_ / np.sum(data_)


def top_k(
    data: np.ndarray, words_txt_path: str, *, K: int = 5
) -> None:
    """Get top-k results according to its probability.
    
    Args:
        data: data result of softmax
        filePath: file in which the infotmation of kinds is recorded
    """
    assert K > 0

    with open(words_txt_path, 'r') as f:
        lines = f.readlines()

    idx = np.flip(np.argsort(data))
    for i, item in enumerate(idx[:K]):
        print(f'Top[{i + 1}] {item} {lines[item].rstrip()}')


def run(
    runner: vart.Runner, img: np.ndarray, words_txt_path: str
) -> None:
    """Run ResNet50.

    Args:
        runner: DPU runner
        img: image to be run
        words_txt_path: path to words.txt
    """    
    # get tensor
    inputTensors = runner.get_input_tensors()
    outputTensors = runner.get_output_tensors()
    input_ndim = tuple(inputTensors[0].dims)
    pre_output_size = int(outputTensors[0].get_data_size() / input_ndim[0])

    output_ndim = tuple(outputTensors[0].dims)
    output_fixpos = outputTensors[0].get_attr('fix_point')
    output_scale = 1 / (2**output_fixpos)

    # prepare batch input/output
    inputData = [np.empty(input_ndim, dtype=np.int8, order='C')]
    outputData = [np.empty(output_ndim, dtype=np.int8, order='C')]

    # init input image to input buffer
    inputData[0] = img.reshape(input_ndim[1:])

    # run
    job_id = runner.execute_async(inputData, outputData)
    runner.wait(job_id)
    
    # softmax & Top-K
    softmax = calc_softmax(outputData[0][0][0][0], output_scale)
    top_k(softmax, words_txt_path)

# %% [markdown]
# ***
#
# ## run

# %%
subdirs = os.listdir(dataset_dir)
img_paths = []
for path in [
    sorted(glob.glob(os.path.join(dataset_dir, d, '*.JPEG')))
    for d in subdirs
]:
    img_paths += path
    
assert len(img_paths)

# %%
g = xir.Graph.deserialize(xmodel_path)
subgraphs = get_child_subgraph_dpu(g)
assert len(subgraphs) == 1  # only one DPU kernel

dpu_runner = vart.Runner.create_runner(subgraphs[0], 'run')
input_fixpos = dpu_runner.get_input_tensors()[0].get_attr('fix_point')
input_scale = 2**input_fixpos

# %%
# test first 100 images
for img_path in img_paths[:100]:
    img = preprocess_one_image(img_path, input_scale)
    run(dpu_runner, img, words_txt_path)
# Out:
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 182 Border terrier
# Top[3] 266 miniature poodle
# Top[4] 184 Irish terrier
# Top[5] 267 standard poodle
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 182 Border terrier
# Top[4] 243 bull mastiff
# Top[5] 170 Irish wolfhound
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 228 komondor
# Top[4] 267 standard poodle
# Top[5] 191 Airedale, Airedale terrier
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 200 Tibetan terrier, chrysanthemum dog
# Top[3] 255 Leonberg
# Top[4] 226 briard
# Top[5] 256 Newfoundland, Newfoundland dog
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 196 miniature schnauzer
# Top[4] 191 Airedale, Airedale terrier
# Top[5] 189 Lakeland terrier
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 200 Tibetan terrier, chrysanthemum dog
# Top[3] 204 Lhasa, Lhasa apso
# Top[4] 153 Maltese dog, Maltese terrier, Maltese
# Top[5] 265 toy poodle
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 226 briard
# Top[3] 184 Irish terrier
# Top[4] 255 Leonberg
# Top[5] 160 Afghan hound, Afghan
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 226 briard
# Top[4] 200 Tibetan terrier, chrysanthemum dog
# Top[5] 160 Afghan hound, Afghan
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 189 Lakeland terrier
# Top[4] 191 Airedale, Airedale terrier
# Top[5] 183 Kerry blue terrier
# Top[1] 184 Irish terrier
# Top[2] 202 soft-coated wheaten terrier
# Top[3] 226 briard
# Top[4] 191 Airedale, Airedale terrier
# Top[5] 200 Tibetan terrier, chrysanthemum dog
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 185 Norfolk terrier
# Top[3] 184 Irish terrier
# Top[4] 189 Lakeland terrier
# Top[5] 182 Border terrier
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 184 Irish terrier
# Top[3] 182 Border terrier
# Top[4] 185 Norfolk terrier
# Top[5] 194 Dandie Dinmont, Dandie Dinmont terrier
# Top[1] 194 Dandie Dinmont, Dandie Dinmont terrier
# Top[2] 265 toy poodle
# Top[3] 202 soft-coated wheaten terrier
# Top[4] 201 silky terrier, Sydney silky
# Top[5] 190 Sealyham terrier, Sealyham
# Top[1] 184 Irish terrier
# Top[2] 202 soft-coated wheaten terrier
# Top[3] 191 Airedale, Airedale terrier
# Top[4] 189 Lakeland terrier
# Top[5] 182 Border terrier
# Top[1] 226 briard
# Top[2] 202 soft-coated wheaten terrier
# Top[3] 255 Leonberg
# Top[4] 175 otterhound, otter hound
# Top[5] 200 Tibetan terrier, chrysanthemum dog
# Top[1] 202 soft-coated wheaten terrier
# Top[2] 226 briard
# Top[3] 200 Tibetan terrier, chrysanthemum dog
# Top[4] 175 otterhound, otter hound
# Top[5] 233 Bouvier des Flandres, Bouviers des Flandres
# Top[1] 194 Dandie Dinmont, Dandie Dinmont terrier
# Top[2] 193 Australian terrier
# Top[3] 202 soft-coated wheaten terrier
# Top[4] 182 Border terrier
# Top[5] 185 Norfolk terrier
# Top[1] 182 Border terrier
# Top[2] 202 soft-coated wheaten terrier
# Top[3] 185 Norfolk terrier
# Top[4] 192 cairn, cairn terrier
# Top[5] 200 Tibetan terrier, chrysanthemum dog
# Top[1] 184 Irish terrier
# Top[2] 202 soft-coated wheaten terrier
# Top[3] 175 otterhound, otter hound
# Top[4] 192 cairn, cairn terrier
# Top[5] 189 Lakeland terrier
# Top[1] 226 briard
# Top[2] 200 Tibetan terrier, chrysanthemum dog
# Top[3] 202 soft-coated wheaten terrier
# Top[4] 204 Lhasa, Lhasa apso
# Top[5] 192 cairn, cairn terrier
# Top[1] 202 soft-coated wheaten terrier
# Top[2]
komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis
# Top[1] 608 jean, blue jean, denim
# Top[2] 514 cowboy boot
# Top[3] 454 bookshop, bookstore, bookstall
# Top[4] 687 organ, pipe organ
# Top[5] 806 sock
# Top[1] 608 jean, blue jean, denim
# Top[2] 692 packet
# Top[3] 696 paintbrush
# Top[4] 842 swimming trunks, bathing trunks
# Top[5] 611 jigsaw puzzle
# Top[1] 608 jean, blue jean, denim
# Top[2] 842 swimming trunks, bathing trunks
# Top[3] 655 miniskirt, mini
# Top[4] 885 velvet
# Top[5] 459 brassiere, bra, bandeau
# Top[1] 608 jean, blue jean, denim
# Top[2] 464 buckle
# Top[3] 502 clog, geta, patten, sabot
# Top[4] 514 cowboy boot
# Top[5] 655 miniskirt, mini
# Top[1] 608 jean, blue jean, denim
# Top[2] 524 cuirass
# Top[3] 597 holster
# Top[4] 464 buckle
# Top[5] 636 mailbag, postbag
# Top[1] 697 pajama, pyjama, pj's, jammies
# Top[2] 608 jean, blue jean, denim
# Top[3] 411 apron
# Top[4] 658 mitten
# Top[5] 911 wool, woolen, woollen
# Top[1] 608 jean, blue jean, denim
# Top[2] 735 poncho
# Top[3] 904 window screen
# Top[4] 76 tarantula
# Top[5] 748 purse
# Top[1] 608 jean, blue jean, denim
# Top[2] 411 apron
# Top[3] 885 velvet
# Top[4] 841 sweatshirt
# Top[5] 697 pajama, pyjama, pj's, jammies
# Top[1] 570 gasmask, respirator, gas helmet
# Top[2] 558 flute, transverse flute
# Top[3] 456 bow
# Top[4] 539 doormat, welcome mat
# Top[5] 413 assault rifle, assault gun
# Top[1] 608 jean, blue jean, denim
# Top[2] 655 miniskirt, mini
# Top[3] 464 buckle
# Top[4] 514 cowboy boot
# Top[5] 806 sock
# Top[1] 843 swing
# Top[2] 830 stretcher
# Top[3] 791 shopping cart
# Top[4] 765 rocking chair, rocker
# Top[5] 515 cowboy hat, ten-gallon hat
# Top[1] 608 jean, blue jean, denim
# Top[2] 474 cardigan
# Top[3] 911 wool, woolen, woollen
# Top[4] 824 stole
# Top[5] 806 sock
# Top[1] 608 jean, blue jean, denim
# Top[2] 806 sock
# Top[3] 824 stole
# Top[4] 474 cardigan
# Top[5] 841 sweatshirt
# Top[1] 585 hair spray
# Top[2] 824 stole
# Top[3] 880 unicycle, monocycle
# Top[4] 740 power drill
# Top[5] 655 miniskirt, mini
# Top[1] 721 pillow
# Top[2] 411 apron
# Top[3] 608 jean, blue jean, denim
# Top[4] 636 mailbag, postbag
# Top[5] 591 handkerchief, hankie, hanky, hankey
# Top[1] 721 pillow
# Top[2] 750 quilt, comforter, comfort, puff
# Top[3] 478 carton
# Top[4] 520 crib, cot
# Top[5] 762 restaurant, eating house, eating place, eatery
# Top[1] 842 swimming trunks, bathing trunks
# Top[2] 608 jean, blue jean, denim
# Top[3] 655 miniskirt, mini
# Top[4] 885 velvet
# Top[5] 775 sarong
# Top[1] 608 jean, blue jean, denim
# Top[2] 591 handkerchief, hankie, hanky, hankey
# Top[3] 655 miniskirt, mini
# Top[4] 474 cardigan
# Top[5] 806 sock
# Top[1] 608 jean, blue jean, denim
# Top[2] 655 miniskirt, mini
# Top[3] 842 swimming trunks, bathing trunks
# Top[4] 741 prayer rug, prayer mat
# Top[5] 464 buckle
# Top[1] 608 jean, blue jean, denim
# Top[2] 655 miniskirt, mini
# Top[3] 514 cowboy boot
# Top[4] 464 buckle
# Top[5] 615 knee pad
# Top[1] 502 clog, geta, patten, sabot
# Top[2] 731 plunger, plumber's helper
# Top[3] 112 conch
# Top[4] 678 neck brace
# Top[5] 998 ear, spike, capitulum
# Top[1] 655 miniskirt, mini
# Top[2] 608 jean, blue jean, denim
# Top[3] 529 diaper, nappy, napkin
# Top[4] 797 sleeping bag
# Top[5] 748 purse
# Top[1] 608 jean, blue jean, denim
# Top[2] 772 safety pin
# Top[3] 474 cardigan
# Top[4] 824 stole
# Top[5] 748 purse
# Top[1] 520 crib, cot
# Top[2] 831 studio couch, day bed
# Top[3] 516 cradle
# Top[4] 750 quilt, comforter, comfort, puff
# Top[5] 797 sleeping bag
# Top[1] 761 remote control, remote
# Top[2] 593 harmonica, mouth organ, harp, mouth harp
# Top[3] 831 studio couch, day bed
# Top[4] 785 seat belt, seatbelt
# Top[5] 765 rocking chair, rocker
# Top[1] 608 jean, blue jean, denim
# Top[2] 806 sock
# Top[3] 911 wool, woolen, woollen
# Top[4] 658 mitten
# Top[5] 841 sweatshirt
# Top[1] 496 Christmas stocking
# Top[2] 721 pillow
# Top[3] 608 jean, blue jean, denim
# Top[4] 785 seat belt, seatbelt
# Top[5] 894 wardrobe, closet, press
# Top[1] 515 cowboy hat, ten-gallon hat
# Top[2] 435 bathtub, bathing tub, bath, tub
# Top[3] 876 tub, vat
# Top[4] 808 sombrero
# Top[5] 793 shower cap
# Top[1] 608 jean, blue jean, denim
# Top[2] 840 swab, swob, mop
# Top[3] 514 cowboy boot
# Top[4] 655 miniskirt, mini
# Top[5] 824 stole
# Top[1] 608 jean, blue jean, denim
# Top[2] 655 miniskirt, mini
# Top[3] 630 Loafer
# Top[4] 842 swimming trunks, bathing trunks
# Top[5] 464 buckle
# Top[1] 692 packet
# Top[2] 893 wallet, billfold, notecase, pocketbook
# Top[3] 533 dishrag, dishcloth
# Top[4] 772 safety pin
# Top[5] 591 handkerchief, hankie, hanky, hankey
# Top[1] 608 jean, blue jean, denim
# Top[2] 885 velvet
# Top[3] 842 swimming trunks, bathing trunks
# Top[4] 655 miniskirt, mini
# Top[5] 459 brassiere, bra, bandeau
# Top[1] 399 abaya
# Top[2] 834 suit, suit of clothes
# Top[3] 982 groom, bridegroom
# Top[4] 608 jean, blue jean, denim
# Top[5] 501 cloak
# Top[1] 608 jean, blue jean, denim
# Top[2] 765 rocking chair, rocker
# Top[3] 474 cardigan
# Top[4] 515 cowboy hat, ten-gallon hat
# Top[5] 799 sliding door
# Top[1] 428 barrow, garden cart, lawn cart, wheelbarrow
# Top[2] 603 horse cart, horse-cart
# Top[3] 830 stretcher
# Top[4] 569 garbage truck, dustcart
# Top[5] 595 harvester, reaper
# Top[1] 608 jean, blue jean, denim
# Top[2] 655 miniskirt, mini
# Top[3] 464 buckle
# Top[4] 842 swimming trunks, bathing trunks
# Top[5] 514 cowboy boot
# Top[1] 608 jean, blue jean, denim
# Top[2] 788 shoe shop, shoe-shop, shoe store
# Top[3] 502 clog, geta, patten, sabot
# Top[4] 478 carton
# Top[5] 770 running shoe
